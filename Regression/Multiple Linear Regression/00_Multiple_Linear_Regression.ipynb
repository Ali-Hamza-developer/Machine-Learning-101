# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv("Salary.csv")
df.head()
# Out:
#    Experience  Age  Salary
# 0           1   25   56000
# 1           3   28   78000
# 2           5   30   98000
# 3           7   32  118000
# 4           9   35  141000

# %%
df.shape
# Out:
# (180, 3)

# %% [markdown]
# # Any Null

# %%
df.isnull().sum()
# Out:
# Experience    0
# Age           0
# Salary        0
# dtype: int64

# %%
# Check Linearity of Both Coulmns if have
sns.pairplot(data=df)
plt.show()

# %%
# How Many values should be Linear we check linearity of our data
sns.heatmap(data=df.corr() , annot=True)
plt.show()

# %% [markdown]
# # Indep and Dep Separate

# %%
x = df.iloc[:,:-1]
y = df["Salary"]

# %% [markdown]
# # Dimension

# %%
x.ndim
# Out:
# 2

# %% [markdown]
# # Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %% [markdown]
# # Train

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Accuracy

# %%
lr.score(x_test, y_test)*100
# Out:
# 99.24957567510782

# %%
lr.coef_
# Out:
# array([5665.77657729, 4560.98094884])

# %%
lr.intercept_
# Out:
# -63757.077940086805

# %%
x.columns
# Out:
# Index(['Experience', 'Age'], dtype='object')

# %% [markdown]
# # Calculation

# %%
# y = m1x1 + m2x2 + c

# %%
# # y = m1x1 + m2x2 + c
# y_pred = 5665.77657729*Experience + 4560.98094884*Age   + -63757.077940086805

# %%
lr.predict(x_test)
# Out:
# array([119645.15720687, 108171.80561726, 240156.65626352,  61598.99893545,
#        140098.67225913,  60494.20330699, 202705.81147938, 260751.9697508 ,
#        306219.98080416,  55933.22235815, 215000.3618274 ,  41145.48388319,
#        270978.72727693, 100296.43778306, 138852.07819565,  70720.96083312,
#        200212.62335244, 141203.46788758, 245680.6344058 , 138030.87943724,
#        142591.86038607,  80947.71835925, 115084.17625803, 291432.24232919,
#        184461.88768403, 247069.02690429, 178937.90954176, 100296.43778306,
#        175339.92578636, 261856.76537926, 265312.95069964, 241119.65345696,
#         75281.94178196, 151430.22541371, 240298.45469854, 276644.50385423])
