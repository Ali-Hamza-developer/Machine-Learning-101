# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("polynomial_classification_dataset_v2.csv")
df.head(5)
# Out:
#       data1     data2  output
# 0  0.398428 -1.921901       1
# 1 -0.143698 -1.574740       1
# 2  0.982027  2.828371       0
# 3  2.620978 -1.914138       0
# 4  1.395433  2.126311       0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="data1", y="data2", data=df, hue ="output" )
plt.show()

# %% [markdown]
# # Separate Indep and Dep Var

# %%
x = df.iloc[:,:-1]
x
# Out:
#         data1     data2
# 0    0.398428 -1.921901
# 1   -0.143698 -1.574740
# 2    0.982027  2.828371
# 3    2.620978 -1.914138
# 4    1.395433  2.126311
# ..        ...       ...
# 395  0.789361 -0.070553
# 396  1.398678 -2.099708
# 397 -2.210594 -1.051944
# 398  1.294950  1.424142
# 399  2.454195 -0.143891
#
# [400 rows x 2 columns]

# %% [markdown]
# # Dimension

# %%
x.ndim
# Out:
# 2

# %%
x = df.iloc[:,:-1]
y= df["output"]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train,  y_test =train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %% [markdown]
# # Train Model

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Accuracy

# %%
lr.score(x_test, y_test)*100
# Out:
# 76.25

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=lr)
plt.show()
